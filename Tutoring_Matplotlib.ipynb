# %% [markdown]
# <a href="https://colab.research.google.com/github/JaeKyunKo/Engineering_Department_Tutoring/blob/main/Tutoring_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Matplotlib**

# %%
import numpy as np #개발자들 사이의 약속 (단축어)
import matplotlib.pyplot as plt #개발자들 사이의 약속 (단축어)

# %% [markdown]
# In order to plot a graph, the dimension of variables should be the same.

# %%
x = np.array([1,2,3]) #3
y = np.array([1,2,3,4]) #4

# %%
plt.plot(x, y) #Different Dimension
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d0d1dfa5badf> in <module>()
# ----> 1 plt.plot(x, y)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
# ...

# %%
x = np.array([1,2,3,4]) #4

# %%
plt.plot(x, y) #Same Dimension

# %% [markdown]
# In order to plot a graph, one needs to use **plt.plot(variable, variable)** method

# %%
x = np.arange(0, 10, 0.001) #Independent Variable
y = np.sin(x) #Dependent Variable f(x)

# %%
print(type(y))
# Out:
# <class 'numpy.ndarray'>

# %%
print(x.shape, y.shape)
# Out:
# (10000,) (10000,)

# %%
plt.plot(x, y)
plt.show()

# %%
x = np.arange(0, 10, 1) #Independent Variable
y = np.sin(x) #Dependent Variable f(x)

# %%
plt.plot(x, y)
plt.show()
